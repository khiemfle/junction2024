# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('faith_under_over_weight.csv')
print(data)
# Out:
#     DATE OF PACKING EXPIRY DATE  AVERAGE WEIGHT (g)  Positive Percentage  \
# 0        2023-10-02  2023-10-29             584.688               81.250
# 1        2023-10-03  2023-11-01             585.969               96.875
# 2        2023-10-03  2023-11-01             591.094              100.000
# 3        2023-10-04  2024-11-01             584.219               87.500
# 4        2023-10-04  2023-11-03             585.031               84.375
# ..              ...         ...                 ...                  ...
# 408      2024-10-18  2024-11-16             581.563               59.375
# 409      2024-10-18  2024-11-16             580.813               56.250
# 410      2024-10-22  2024-11-17             567.750                3.125
# 411      2024-10-22  2024-11-17             585.438               81.250
# 412      2024-10-24  2024-11-21             585.250               84.375
#
#      Negative Percentage
# 0                  0.000
# 1                  3.125
# ...

# %%
print(data['Positive Percentage'].sum()/len(data['Positive Percentage']))
# Out:
# 77.54993946731234

# %%
print(data['Negative Percentage'].sum()/len(data['Positive Percentage']))
# Out:
# 17.531779661016948

# %%
plt.hist(data['Positive Percentage'], bins=20, edgecolor='k', alpha=0.5, label='Positive')
plt.xlabel('Overweight Percentage')
plt.ylabel('Frequency')
plt.title('Overweight Percentage Distribution')
plt.show()
